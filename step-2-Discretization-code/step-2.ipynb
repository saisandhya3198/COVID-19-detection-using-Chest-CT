# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
plt.rc("font", size=14)
# %matplotlib inline

# %%
df = pd.read_csv('dataset.csv')
df = df.drop(columns = 'Index')

# %%
df
# Out:
#       Energy  Correlation  Dissimilarity  Homogenity     Contrast  class_label
# 0   0.019349     0.867882      18.958477    0.099115  1128.419845            0
# 1   0.018590     0.895155      16.439161    0.099919   734.834338            0
# 2   0.020157     0.904695      16.137180    0.115214   782.162402            0
# 3   0.112826     0.943806      12.886319    0.287135   841.671875            0
# 4   0.112826     0.943806      12.886319    0.287135   841.671875            0
# 5   0.119517     0.942602      13.027313    0.297123   853.388410            0
# 6   0.119517     0.942602      13.027313    0.297123   853.388410            0
# 7   0.124367     0.940236      13.142286    0.303815   879.873708            0
# 8   0.122299     0.937820      13.223241    0.294432   866.365342            0
# 9   0.043661     0.941740      10.756582    0.218150   523.159879            0
# 10  0.035821     0.877649      14.102854    0.195065  1176.618356            0
# ...

# %%
print(df.dtypes)
print(df.shape)
# Out:
# Energy           float64
# Correlation      float64
# Dissimilarity    float64
# Homogenity       float64
# Contrast         float64
# class_label        int64
# dtype: object
# (31, 6)

# %%
df.isna().sum()/len(df)*100
#no NULL values in the dataset
# Out:
# Energy           0.0
# Correlation      0.0
# Dissimilarity    0.0
# Homogenity       0.0
# Contrast         0.0
# class_label      0.0
# dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns = 'class_label')
y = df['class_label']
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
clf = DecisionTreeClassifier(max_depth=3, random_state=1234)
model = clf.fit(X, y)

# %%
#df['Energy'].describe()

# %%
cut_labels = ['low', 'medium', 'high']
cut_bins = [0 , df['Energy'].min(), df['Energy'].mean(), df['Energy'].max()]
df['Energy'] = pd.cut(df['Energy'], bins=cut_bins, labels=cut_labels)
df
# Out:
#     Energy  Correlation  Dissimilarity  Homogenity     Contrast  class_label
# 0   medium     0.867882      18.958477    0.099115  1128.419845            0
# 1      low     0.895155      16.439161    0.099919   734.834338            0
# 2   medium     0.904695      16.137180    0.115214   782.162402            0
# 3     high     0.943806      12.886319    0.287135   841.671875            0
# 4     high     0.943806      12.886319    0.287135   841.671875            0
# 5     high     0.942602      13.027313    0.297123   853.388410            0
# 6     high     0.942602      13.027313    0.297123   853.388410            0
# 7     high     0.940236      13.142286    0.303815   879.873708            0
# 8     high     0.937820      13.223241    0.294432   866.365342            0
# 9   medium     0.941740      10.756582    0.218150   523.159879            0
# 10  medium     0.877649      14.102854    0.195065  1176.618356            0
# ...

# %%
#df['Correlation'].describe()

# %%
cut_labels = ['low', 'high']
cut_bins = [0, df['Correlation'].mean(), df['Correlation'].max()]
df['Correlation'] = pd.cut(df['Correlation'], bins=cut_bins, labels=cut_labels)
df
# Out:
#     Energy Correlation  Dissimilarity  Homogenity     Contrast  class_label
# 0   medium         low      18.958477    0.099115  1128.419845            0
# 1      low         low      16.439161    0.099919   734.834338            0
# 2   medium         low      16.137180    0.115214   782.162402            0
# 3     high        high      12.886319    0.287135   841.671875            0
# 4     high        high      12.886319    0.287135   841.671875            0
# 5     high        high      13.027313    0.297123   853.388410            0
# 6     high        high      13.027313    0.297123   853.388410            0
# 7     high        high      13.142286    0.303815   879.873708            0
# 8     high        high      13.223241    0.294432   866.365342            0
# 9   medium        high      10.756582    0.218150   523.159879            0
# 10  medium         low      14.102854    0.195065  1176.618356            0
# ...

# %%
#df['Dissimilarity'].describe()

# %%
cut_labels = ['low', 'high']
cut_bins = [0, df['Dissimilarity'].mean(), df['Dissimilarity'].max()]
df['Dissimilarity'] = pd.cut(df['Dissimilarity'], bins=cut_bins, labels=cut_labels)
df
# Out:
#     Energy Correlation Dissimilarity  Homogenity     Contrast  class_label
# 0   medium         low          high    0.099115  1128.419845            0
# 1      low         low          high    0.099919   734.834338            0
# 2   medium         low          high    0.115214   782.162402            0
# 3     high        high          high    0.287135   841.671875            0
# 4     high        high          high    0.287135   841.671875            0
# 5     high        high          high    0.297123   853.388410            0
# 6     high        high          high    0.297123   853.388410            0
# 7     high        high          high    0.303815   879.873708            0
# 8     high        high          high    0.294432   866.365342            0
# 9   medium        high           low    0.218150   523.159879            0
# 10  medium         low          high    0.195065  1176.618356            0
# ...

# %%
#df['Homogenity'].describe()

# %%
cut_labels = ['low', 'high']
cut_bins = [0, df['Homogenity'].mean(), df['Homogenity'].max()]
df['Homogenity'] = pd.cut(df['Homogenity'], bins=cut_bins, labels=cut_labels)
df
# Out:
#     Energy Correlation Dissimilarity Homogenity     Contrast  class_label
# 0   medium         low          high        low  1128.419845            0
# 1      low         low          high        low   734.834338            0
# 2   medium         low          high        low   782.162402            0
# 3     high        high          high       high   841.671875            0
# 4     high        high          high       high   841.671875            0
# 5     high        high          high       high   853.388410            0
# 6     high        high          high       high   853.388410            0
# 7     high        high          high       high   879.873708            0
# 8     high        high          high       high   866.365342            0
# 9   medium        high           low        low   523.159879            0
# 10  medium         low          high        low  1176.618356            0
# 11  medium         low          high        low  1262.386565            0
# ...

# %%
#df['Contrast'].describe()

# %%
cut_labels = ['less', 'more']
cut_bins = [0, df['Contrast'].mean(), df['Contrast'].max()]
df['Contrast'] = pd.cut(df['Contrast'], bins=cut_bins, labels=cut_labels)
df
# Out:
#     Energy Correlation Dissimilarity Homogenity Contrast  class_label
# 0   medium         low          high        low     more            0
# 1      low         low          high        low     more            0
# 2   medium         low          high        low     more            0
# 3     high        high          high       high     more            0
# 4     high        high          high       high     more            0
# 5     high        high          high       high     more            0
# 6     high        high          high       high     more            0
# 7     high        high          high       high     more            0
# 8     high        high          high       high     more            0
# 9   medium        high           low        low     less            0
# 10  medium         low          high        low     more            0
# 11  medium         low          high        low     more            0
# ...

# %%
df.columns
# Out:
# Index(['Energy', 'Correlation', 'Dissimilarity', 'Homogenity', 'Contrast',
#        'class_label'],
#       dtype='object')

# %%
df.loc[df.class_label == 0, 'class_label'] = 'Yes'
df.loc[df.class_label == 1, 'class_label'] = 'No'
df
# Out:
#     Energy Correlation Dissimilarity Homogenity Contrast class_label
# 0   medium         low          high        low     more         Yes
# 1      low         low          high        low     more         Yes
# 2   medium         low          high        low     more         Yes
# 3     high        high          high       high     more         Yes
# 4     high        high          high       high     more         Yes
# 5     high        high          high       high     more         Yes
# 6     high        high          high       high     more         Yes
# 7     high        high          high       high     more         Yes
# 8     high        high          high       high     more         Yes
# 9   medium        high           low        low     less         Yes
# 10  medium         low          high        low     more         Yes
# 11  medium         low          high        low     more         Yes
# 12  medium         low          high        low     less         Yes
# ...

# %%
import arff
arff.dump('b_dataset.arff'
      , df.values
      , relation='b_dataset'
      , names=df.columns)

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
df.columns

# %%
from sklearn import tree

#method-1 to get raw rule representation
text_representation = tree.export_text(clf, feature_names=['Energy', 'Corr', 'Diss_sim', 'Homogen', 'Contrast', 'Energy2',
       'Corr2', 'Diss_sim2', 'Homogen2', 'Contrast2', 'Energy3', 'Corr3',
       'Diss_sim3', 'Homogen3', 'Contrast3', 'Energy4', 'Corr4', 'Diss_sim4',
       'Homogen4', 'Contrast4', 'Energy5', 'Corr5', 'Diss_sim5', 'Homogen5',
       'Contrast5'])
print(text_representation)

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    feature_names = [f.replace(" ", "_")[:-5] for f in feature_names]
    print("def predict({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "    " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, np.round(threshold,2)))
            recurse(tree_.children_left[node], depth + 1)
            print("{}else:  # if {} > {}".format(indent, name, np.round(threshold,2)))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)

# %%
#method-2 to get if-else like coded rules
feature_names = ['Energy', 'Corr', 'Diss_sim', 'Homogen', 'Contrast', 'Energy2',
       'Corr2', 'Diss_sim2', 'Homogen2', 'Contrast2', 'Energy3', 'Corr3',
       'Diss_sim3', 'Homogen3', 'Contrast3', 'Energy4', 'Corr4', 'Diss_sim4',
       'Homogen4', 'Contrast4', 'Energy5', 'Corr5', 'Diss_sim5', 'Homogen5',
       'Contrast5']
tree_to_code(clf,feature_names)

# %%
def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        rule += " then "
        if class_names is None:
            rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules

# %%
#method-3 to get sentence-like rules
rules = get_rules(clf, feature_names, [0,1])
for r in rules:
    print(r)

# %%
df['Corr'].describe()

# %%
df['Energy'].describe()

# %%
from sklearn.preprocessing import KBinsDiscretizer

# %%
discretizer = KBinsDiscretizer(n_bins=2, encode='ordinal', strategy='uniform')

# %%
X = df.drop(columns = 'class_label')
y = df['class_label']
X_binned = discretizer.fit_transform(X)
X_binned

# %%
from sklearn.tree import DecisionTreeClassifier 

clf = DecisionTreeClassifier(max_depth=3, random_state=1234)
model = clf.fit(X_binned, y)

from sklearn import tree

#method-1 to get raw rule representation
text_representation = tree.export_text(clf, feature_names=['Energy', 'Corr', 'Diss_sim', 'Homogen', 'Contrast', 'Energy2',
       'Corr2', 'Diss_sim2', 'Homogen2', 'Contrast2', 'Energy3', 'Corr3',
       'Diss_sim3', 'Homogen3', 'Contrast3', 'Energy4', 'Corr4', 'Diss_sim4',
       'Homogen4', 'Contrast4', 'Energy5', 'Corr5', 'Diss_sim5', 'Homogen5',
       'Contrast5'])
print(text_representation)
